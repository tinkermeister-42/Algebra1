# %%
# %run "~/Documents/Algebra1/tools/LinearEquations.py"

# %%
fig, ax = quadratic_function_coordinate_plane(
    x_axis=(-5, 5, "x", {"major_step": 1}),#, "minor_step": 0.5}),
    y_axis=(-5, 5, "y", {"major_step": 1}),#, "minor_step": 0.5}),
    quadratics=[
        #(1, 0, 0),                  # y = x^2
        (-0.5, 2, -1, {"color": "C0"})
    ],
    #inequalities=[(1, 0, -4, "<=")],  # y ≤ x^2 - 4
    lines=[(None, 2, {"linestyle":"--", "color": "red"})],
    points=[(2, 1, "vertex", {"color": "red", "zorder": 10, "s": 50})],
    show_vertex=False,#True,
    show_roots=False,#True,
    # chart_axis_labels={
    #     "bottom": ("x", {}),
    #     "left": ("y", {}),
    # },
)

# %%
y = 2(x - 4)^2 + 7 => 2x^2 - 16x + 23
# Out:
#   Cell In[191], line 1
#     y = 0.5(x - 1)^2 - 1 = 2x^2 - 4x
#                            ^
# SyntaxError: invalid decimal literal

# %%
pts = {"color": "red", "zorder": 10, "s": 50}

fig, ax = quadratic_function_coordinate_plane(
    x_axis=(-2, 6, "x", {"major_step": 1,"minor_step": 1}),
    y_axis=(-6, 6, "y", {"major_step": 1, "minor_step": 1}),
    aspect=0.5,
#    centered_axes=False,
    quadratics=[
        (1, -4, 1),                  # y = x^2
        #(-0.5, 2, -1, {"color": "C0"})
    ],
    #inequalities=[(1, 0, -4, "<=")],  # y ≤ x^2 - 4
     lines=[(None, 2, {"linestyle":"--", "color": "gray"})],
     points=[(3, -2, "", pts), (1, -2, "", pts), (2, -3, "", pts)],
    legend=False,
    #outfile="../images/Unit_6/Lesson_1/Example7.png"
)

plt.savefig("../images/Unit_6/Lesson_2/Example2C.png",bbox_inches="tight")

# %%
pts = {"color": "red", "zorder": 10, "s": 50}

fig, ax = quadratic_function_coordinate_plane(
    x_axis=(-2, 4, "x", {"major_step": 1,"minor_step": 1}),
    y_axis=(2, 10, "y", {"major_step": 1, "minor_step": 1}),
    aspect=0.5,
    centered_axes=False,
    quadratics=[
        (3, -6, 7),                  # y = x^2
        #(-0.5, 2, -1, {"color": "C0"})
    ],
    #inequalities=[(1, 0, -4, "<=")],  # y ≤ x^2 - 4
     lines=[(None, 1, {"linestyle":"--", "color": "gray"})],
     points=[ (1, 4, "", pts)],
    legend=False,
    #outfile="../images/Unit_6/Lesson_1/Example7.png"
)

plt.savefig("../images/Unit_6/Lesson_2/YouTry1.png",bbox_inches="tight")
