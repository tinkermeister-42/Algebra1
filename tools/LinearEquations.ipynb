# %%
# %load_ext autoreload
# %autoreload 2

# %%
from LinearEquations import linear_function_coordinate_plane

# %%
pkwgs = {"s":50, "zorder": 10, "color": "blue"}

pkwgs2 = {"s":50, "zorder": 10, "color": "red"}

linear_function_coordinate_plane(
    x_axis=(-10, 10, "x", {"major_step": 1, "minor_step": 1}),
    y_axis=(-10, 10, "y", {"major_step": 1, "minor_step": 1}),
    centered_axes=True,
    #chart_axis_labels={"bottom":["miles",{}], "left": ["Cost ($)",{}]},
    axis_arrows=True,
    #axis_arrow_ends={"x": None, "y": None},
    axis_baseline=True,
    #aspect=.3,
    #points=[
    #    (3, -4, "(2,-4)", {"s":50, "zorder":10, "color":"green"}),
    #    (-4, 5, "(-4,6)", {"s":50, "zorder":10, "color":"red"})
    #],
    #lines = [(2.25, 3, {"label": "Taxi"}), (3.75, 0, {"label": "Ride-Share"})],
    inequalities = [
        (-3/2, -3, ">="),  # y ≥ 0.5x - 1 (solid boundary)
    ],
    show_quadrants=False,
    legend=False,#True,
    quadrant_label_style="short",
    project_to_axes=False,#True,
   # title="Cost of Taxi vs. Ride-Sharing",
    outfile="../images/Unit_4/Lesson_6/Example6.png"
)
# Out:
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %%
linear_function_coordinate_plane(
    x_axis=(-10, 10, "x-axis", {"major_step": 2, "minor_step": 1}),
    y_axis=(-10, 10, "y-axis", {"major_step": 2, "minor_step": 1}),
    centered_axes=True,
    axis_arrows=True,
    axis_arrow_ends={"x": "both", "y": "both"},
    axis_baseline=True,
    points=[(0, 0, "origin", {"s": 75, "zorder": 10})],
    show_quadrants=True,
    quadrant_label_style="short",
    title="Coordinate Plane",
    title_fontsize=22,
    outfile="../images/Unit_4/Lesson_1/CartesianCoordinatePlane.png"
)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Coordinate Plane'}>)

# %%
linear_function_coordinate_plane(
    x_axis=(
        0,
        1000,
        "x",
        {"major_step": 100, "format": "{:,.0f}"},
    ),  # 0,100,200,...,1000
    y_axis=(0, 10, "y", {"major_step": 1, "minor_step": 0.5, "format": "{:.1f}"}),
    centered_axes=False,  # chart look
    aspect="auto",  # let the figure fill naturally
    chart_axis_labels={
        "bottom": ("Hours", {"fontsize": 12}),
        "left": ("Dollars", {"fontsize": 12}),
    },
    lines=[(8, 10, {"linewidth": 2.2})],  # f(x) = 8x + 10
    title="Chart Axes • 0→1000 by 100 • Outside Labels",
    frame_box=True,
    frame_kwargs={"linewidth": 1.5},
)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Chart Axes • 0→1000 by 100 • Outside Labels'}>)

# %%
linear_function_coordinate_plane(
    x_axis=(-6, 6, "x", {"major_step": 2}),
    y_axis=(-6, 6, "y", {"major_step": 2}),
    centered_axes=True,
    axis_arrows=True,
    axis_arrow_ends={"x": "pos", "y": "pos"},
    inequalities=[
        (0.5, -1, ">=", {"alpha": 0.12}),  # y ≥ 0.5x - 1 (solid boundary)
        (-1, 2, "<", {"alpha": 0.12}),  # y < -x + 2 (dashed boundary)
    ],
    title="Inequalities • Inclusive vs. Strict",
    frame_box=True,
    frame_inset=0.01,
)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Inequalities • Inclusive vs. Strict'}>)

# %%
linear_function_coordinate_plane(
    x_axis=(
        0,
        72,
        "x",
        {"ticks": [0, 12, 24, 36, 48, 60, 72], "format": "{:.0f} min", "rotate": 0},
    ),
    y_axis=(0, 120, "y", {"major_step": 20, "format": "{:.0f} bpm"}),
    centered_axes=False,
    aspect="auto",
    title="Explicit Ticks • Formatted Labels",
    lines=[(1.2, 20, {"linewidth": 2})],
    points=[(36, 63, "Halfway", {"s": 36})],
    frame_box=True,
)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Explicit Ticks • Formatted Labels'}>)

# %%
linear_function_coordinate_plane(
    x_axis=(-10, 10, "x", {"major_step": 5, "minor_step": 1, "hide_zero_label": True}),
    y_axis=(-20, 20, "y", {"major_step": 5, "minor_step": 1, "hide_zero_label": True}),
    centered_axes=True,
    aspect=0.8,  # height/width ratio
    title="Major+Minor Ticks • Hide 0 • Numeric Aspect",
    lines=[(2, 0), (-0.5, 4)],
    frame_box=True,
    frame_inset=0.01,
)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Major+Minor Ticks • Hide 0 • Numeric Aspect'}>)

# %%
linear_function_coordinate_plane(
    x_axis=(0, 10, "x", {"major_step": 1}),
    y_axis=(0, 100, "y", {"major_step": 10}),
    centered_axes=False,
    aspect="auto",
    grid_labels={
        "bottom": [(5, "Midpoint", {"fontsize": 10})],
        "left": [(80, "Target", {"fontsize": 10, "rotation": 90})],
    },
    points=[(2, 20, "A"), (8, 64, "B")],
    axis_arrows=True,
    axis_arrow_ends={"x": "pos", "y": "pos"},
    title="Edge Grid Labels • Points • Chart Axes",
    frame_box=True,
)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Edge Grid Labels • Points • Chart Axes'}>)

# %%
linear_function_coordinate_plane(
    x_axis=(-5, 5, "x", {"major_step": 1}),
    y_axis=(-5, 10, "y", {"major_step": 1}),
    centered_axes=True,
    axis_arrows=True,
    lines=[(2, 1, {"linewidth": 2.4})],  # y = 2x + 1
    points=[(-2, -3), (-1, -1), (0, 1), (1, 3), (2, 5)],
    title="Constant Rate of Change (Preview of Slope)",
    frame_box=True,
    frame_inset=0.01,
    # outfile="unit4_linear_plane_example.png"  # <- saves a PNG at 300dpi
)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Constant Rate of Change (Preview of Slope)'}>)

# %%
linear_function_coordinate_plane(
    x_axis=(-12, 12, "x", {"major_step": 3, "minor_step": 1}),
    y_axis=(-8, 14, "y", {"major_step": 2, "minor_step": 1}),
    centered_axes=True,
    aspect="auto",
    axis_arrows=True,
    axis_arrow_ends={"x": "both", "y": "both"},
    axis_baseline=True,
    inequalities=[(0.5, -1, ">=", {"alpha": 0.10}), (-1, 6, "<", {"alpha": 0.10})],
    lines=[(1, 0, {"linewidth": 2.2}), (0.25, 2, {"linewidth": 2.2})],
    points=[(6, 3, "P"), (-4, 7, "Q")],
    grid_labels={
        "right": [(10, "Cap", {"fontsize": 9})],
        "top": [(8, "Limit", {"fontsize": 9})],
    },
    title="Everything Demo • Centered + Arrows + Inequalities + Lines + Ticks + Frame",
    frame_box=True,
    frame_inset=0.012,
    frame_kwargs={"linewidth": 1.4},
)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Everything Demo • Centered + Arrows + Inequalities + Lines + Ticks + Frame'}>)
